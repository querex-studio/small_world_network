# %% [markdown]
# # <center> **Small World Network** </center>
#
# <p align="center"> <strong>Arash Ghahraman</strong> </p>
# <center> Eötvös Loránd University </center>

# %% [markdown]
# # **introduction: Social Media**

# %% [markdown]
# As a simple definition, **Social media** is a collection of websites, applications and other platforms that enable us to share or create content and also helps us to participate in social networking. It is not only limited to blogging and sharing pictures, but there are also many vigorous tools that social media provides because it has great influence and is far-reaching.
#
# We cannot ignore the fact that social media is one of the biggest elements present in our lives today. We can get any information, talk to anyone in any corner of the world at a fast speed. Therefore, social media plays a big role in our lives today. Everything that is so widely expanded has both positivity and negativity. The power of social media is immense and it affects everyone. Today it is difficult to imagine our lives with social media and we pay the price for excessive usage. Overall there is a lot of debate about the effects of social media.
#
# Among websites and applications, Twitter is one of the most popular environment. it is the coolest way for individuals to form their network.
#
# >Since the 2017, I have seen even more unique and interesting uses of social media data across a wide variety of research disciplines, such as sociology, computer science, media and communication, political science, and engineering to name only a few. Social media platforms generate a vast amount of data on a daily basis on a variety of topics and consequently represent a key source of information for anyone seeking to study 21st century society.

# %% [markdown]
# ## **Social Media Analytics**
# Social media analytics (SMA) refers to the approach of collecting data from social media sites and blogs and evaluating that data to make business decisions. This process goes beyond the usual monitoring or a basic analysis of retweets or ‘likes’ to develop an in-depth idea of the social consumer.

# %% [markdown]
# Method | Description
# --- | ---
# Content Analysis	| Content analysis can be used for systematically labelling text, audio, and/or visual communication from social media, and can provide a numerical output. <br> An example study using content analysis on tweets can be accessed [here](http://eprints.whiterose.ac.uk/126728/).<br> A useful overview of the method can be found [here](https://books.google.co.uk/books?hl=en&lr=&id=nE1aDwAAQBAJ&oi=fnd&pg=PP1&dq=Krippendorff,+K&ots=yYcmYokQct&sig=MtZxvW-zAZgeD5ZIt-WzDDFBIQc%20-%20v=onepage&q=Krippendorff%2C%20K&f=false#v=snippet&q=Krippendorff%2C%20K&f=false). <br>It is fine to take a systematic random sample of between 1% to 10% of the dataset depending on the volume of data retrieved.
# Thematic Analysis	| Thematic analysis involves a rigorous process in order to locate patterns within data through data familiarisation, coding, and developing and revising themes.<br> An example of a study using thematic analysis can be found [here](https://onlinelibrary.wiley.com/doi/full/10.1111/hir.12247).<br> A useful guide in applying thematic analysis can be found [here](https://www.tandfonline.com/doi/abs/10.1191/1478088706qp063oa).<br> Thematic analysis may also be known as discourse analysis. Similar to content analysis it is fine to take a systematic random sample of between 1% to 10% of the dataset <br> depending on the volume of data retrieved.
# Social Network Analysis	| Social network analysis can be used to measure and map the relationships between individuals, organisations, Web Pages, and information and/or knowledge entities.<br> See [this](https://link.springer.com/article/10.1007/s00038-018-1192-5) article and the supplementary material for insight into how to incorporate social network analysis into a study.<br> A useful resource on analysing social media data using social network analysis can be accessed [here](https://books.google.co.uk/books?hl=en&lr=&id=rbxPm93PRY8C&oi=fnd&pg=PP1&dq=social+network+analysis+nodexl&ots=MyiF93ZpH0&sig=iC4z9T9LwBaPPE1eZy8g9D446j8%20-%20v=onepage&q=social%20network%20analysis%20nodexl&f=false#v=snippet&q=social%20network%20analysis%20nodexl&f=false).
# Machine Learning	| Machine learning is a type of artificial intelligence which allows computers to learn without being programmed.<br> It may also involve humans labelling a subset of data and allows the computer to learn and code the remainder of the data.<br> A study using machine learning to analyse Twitter user profiles can be accessed [here](https://arxiv.org/pdf/1406.1335.pdf).
# Semantic Analysis (Linguistics)	| Semantic analysis may examine the meaning of language used and also the relationship between occurrences of words, phrases, and clauses.<br> A useful presentation which uses semantic analysis to examine Twitter can be accessed [here](https://www.researchgate.net/profile/Mark_Mcglashan/publication/325946518_What_your_followers_say_about_you_a_dialectical-relational_approach_to_collective_identity_in_the_followership_of_an_online_protest_movement/links/5b2e0d250f7e9b0df5be96e2/What-your-followers-say-about-you-a-dialectical-relational-approach-to-collective-identity-in-the-followership-of-an-online-protest-movement.pdf?origin=publication_detail). It describes a study by Dr. Mark McGlashan.
# Time Series Analysis	| Time series analysis is rarely used a method within itself and is usually combined with other methods. It plots the frequency of social media across time.<br> It is often used to complement other types of analysis.<br> This [paper](http://etheses.whiterose.ac.uk/20367/) provides an example of utilising time series analysis alongside other research methods such as content and thematic analysis.

# %% [markdown]
# # **Twitter**

# %% [markdown]
# Twitter remains the most popular platform for academic research, as it still provides its data via a number of Application Programming Interfaces (API).
#
# Studies in social media can be framed by drawing on a wide-variety of theories, constructs and conceptual frameworks from a wide-variety of disciplines and I would recommend taking a look at [this paper](https://www.sciencedirect.com/science/article/pii/S026840121400098X) which nicely summarises a number of these approaches.

# %% [markdown]
# ## **Data Acquisition**

# %% [markdown]
# Many endpoints on the Twitter developer platform use the OAuth 1.0a method to act, or make API requests, on behalf of a Twitter account.

# %% [markdown]
# ### Twitter API
# In order to get access to the Tweepy API, it is important for you to create a developer account and this account must be approved from twitter.

# %% [markdown]
# Here is how you can create a developer account
# * Visit the twitter developer site at [dev.twitter.com](dev.twitter.com)
# * Create an account on the developer site by clicking the ‘Sign In’ button at the top-right corner.
# * After sign-in, click on the developer link on the nav-bar.
# * Click on your account and choose “Apps” from the drop-down menu that appears.
# * Click on the “create app” button and fill in the details for your application
# * Create your access token for the application. Copy this access token into a file and keep it safe
# * Once you’ve done this, make a note of your OAuth settings, which include – Consumer Key, Consumer Secret, OAuth Access Token, OAuth Access Token Secret

# %% [markdown]
# #### Import libraries

# %%
# Basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install oauth2

# %% [markdown]
# there are a number of applications to get data from Twitter such as **tweepy**, **twitter**, etc. One can also use twitter's API directly. However, there is some restrictions.

# %%
import oauth2 as oauth
import tweepy
import json
import csv

# %% [markdown]
# #### Credential Variables

# %% [markdown]
# to get Keys and Secret codes, visit the [twitter developer site](dev.twitter.com)

# %%
# Variables that contains the user credentials to access Twitter API
import twitter_credentials as cred

CONSUMER_KEY = cred.CONSUMER_KEY
CONSUMER_SECRET = cred.CONSUMER_SECRET
ACCESS_KEY = cred.ACCESS_KEY
ACCESS_SECRET = cred.ACCESS_SECRET
#===============================================================================

# %% [markdown]
# #### Simple access

# %% [markdown]
# a simple code to get data from Twitter.

# %%
# I)
'''
#to save the personal information as a json file in the same directory
with open('twitter_credentials.json', 'w') as secret_info:
    json.dump(twitter_cred, secret_info, indent=4, sort_keys=True)

'''
# This is the simplest way to get tweets
consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
access_token = oauth.Token(key=ACCESS_KEY, secret=ACCESS_SECRET)
client = oauth.Client(consumer, access_token)

timeline_endpoint = "https://api.twitter.com/1.1/statuses/home_timeline.json"
response, data = client.request(timeline_endpoint)

tweets = json.loads(data)

# %%
tweets[1]['id_str']
# Out:
# '1343996919127842816'

# %%
for tweet in tweets:
    print (tweet['text'])
# Out:
# RT @ctr4neurotech: Congrats to Kat Steele, CNT member @UW and @doituw 2020 Trailblazer Award Winner. Recipients of this award have increase…
# RT @fringetracker: Very sad to hear from her daughter that Arianna Wright Rosenbluth, the pioneering physicist and computer scientist who w…
# RT @FrancoLabUCLA: @CSSIEEE president Anuradha Annaswamy @aanna_mit will be our keynote speaker at #IEEEMED2021 in #Bari,  (Italy, hybrid m…
# في ميلاد السيد المسيح نبارك لكل مسيحيي شرقنا الأصيل لاسيما الذين يشاركوننا الإنسانية والوطن منذ فجر التاريخ والحضار… https://t.co/U52YpsjJPz
# .@realDonaldTrump uses a worthless photo to recklessly accuse Iran.
#
# Last time, the US ruined our region over WMD f… https://t.co/VSKpTbuxW0
# The birth of Spirit of God—Jesus, revered by all Muslims as a great prophet—is a joyous occasion for ALL mankind.… https://t.co/1l5HKqr7Ri
# ...

# %% [markdown]
# Here, we define a fi=unction so called **oauth_req**, to get data

# %%
def oauth_req(url, key, secret, http_method="GET", post_body="", http_headers=None):
    consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
    access_token = oauth.Token(key=ACCESS_KEY, secret=ACCESS_SECRET)
    client = oauth.Client(consumer, access_token)
    response, content = client.request( url, method=http_method, body=post_body.encode('utf-8'), headers=http_headers )
    return content

home_timeline = oauth_req( 'https://api.twitter.com/1.1/statuses/home_timeline.json', key=ACCESS_KEY, secret=ACCESS_SECRET)

# %%
tweets = json.loads(home_timeline)
len(tweets)
# Out:
# 20

# %%
url="https://api.twitter.com/1.1/account/settings.json"

new_setting=oauth_req( url, key=ACCESS_KEY, secret=ACCESS_SECRET)

# %%
# conver the ouptput into DataFrame
data=pd.DataFrame(tweets)
data.head()
# Out:
#                        created_at  ...  possibly_sensitive_appealable
# 0  Wed Dec 30 02:26:13 +0000 2020  ...                            NaN
# 1  Tue Dec 29 19:06:50 +0000 2020  ...                            NaN
# 2  Tue Dec 29 19:01:59 +0000 2020  ...                            NaN
# 3  Fri Dec 25 09:14:05 +0000 2020  ...                            NaN
# 4  Thu Dec 24 12:12:49 +0000 2020  ...                          False
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Tweepy

# %% [markdown]
# One can use other libraries such as Tweepy and Twitter. for the sake of simplisity, we use Tweepy.

# %% [markdown]
# #### Search a term

# %%
# III) Search method
# Before you can utilize Tweepy it requires authorization
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

#===============================================================================
# Insert the keyword, what you are looking for
searchString = "iran"

# We use pagination a lot in Twitter API development. Iterating through
#    timelines, user lists, direct messages, etc.
# In order to perform pagination we must supply a page/cursor parameter with
#    each of our requests.
# To help make pagination easier and require less code Tweepy has the Cursor object.

cursor = tweepy.Cursor(api.search, q=searchString, count=100,
                       lang="en",
                       tweet_mode='extended')

# for more information once can refer to http://docs.tweepy.org/en/latest/api.html

#===============================================================================

maxCount = 100
count = 0
tweets = []
for tweet in cursor.items():
    print()
    print("Tweet Information")
    print("================================")
    print("Text: ", tweet.full_text)
    tweets.append(tweet.full_text)
    print("Geo: ", tweet.geo)
    print("Coordinates: ", tweet.coordinates)
    print("Place: ", tweet.place)
    print()

    print("User Information")
    print("================================")
    print("Location: ", tweet.user.location)
    print("Geo Enabled? ", tweet.user.geo_enabled)

    count = count + 1
    if count == maxCount:
        break;
# Out:
# Tweet Information
# ...
# Text:  RT @TeaPainUSA: If Trump had led us into deadly hot wars with North Korea and Iran, the death toll wouldn't even be close to the number of…
# Geo:  None
# Coordinates:  None
# Place:  None
#
# User Information
# ...
# Location:  Harrisburg, Pa
# Geo Enabled?  False
#
# Tweet Information
# ...
# Text:  RT @kaitlancollins: While in Mar-a-Lago, Trump has been almost single-mindedly focused on the election, though at one point he also said he…
# Geo:  None
# Coordinates:  None
# Place:  None
#
# User Information
# ...
# Location:  The South
# Geo Enabled?  False
#
# Tweet Information
# ...
# Text:  RT @kaitlancollins: While in Mar-a-Lago, Trump has been almost single-mindedly focused on the election, though at one point he also said he…
# Geo:  None
# Coordinates:  None
# Place:  None
#
# User Information
# ...
# Location:
# Geo Enabled?  False
#
# Tweet Information
# ...

# %%
df = pd.DataFrame(tweets, columns=['text'])

print(df.head())
print(len(df))
# Out:
#                                                 text
# 0  RT @TeaPainUSA: If Trump had led us into deadl...
# 1  RT @kaitlancollins: While in Mar-a-Lago, Trump...
# 2  RT @kaitlancollins: While in Mar-a-Lago, Trump...
# 3  RT @realDonaldTrump: ...The consent decree sig...
# 4  RT @HeshmatAlavi: Poster of #Iran's terrorist-...
# 100

# %% [markdown]
# #### Streaming

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %%
class StdOutListener(StreamListener):
    def on_data(self, status):
      if len(aa)< 90 :
        tweet = json.loads(status)
        print (tweet['text'])
        # save data in an array
        aa.append(tweet)
        #save data in file
        with open('fetched_tweets.txt','a') as tf:
            tf.write(status)
        return True
      else:
        print('Limit threshold exceeded')
        return False

    def on_error(self, status):
        print (status)

# %%
aa = []
#===============================================================================
l = StdOutListener()

auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY , ACCESS_SECRET )
stream = Stream(auth, l)

#This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
stream.filter(track=['python', 'pycon', 'twitter'], languages=["en"])
# Out:
# RT @seokwu_u: i cannot, CANNOT decide the funniest part of this photo https://t.co/UVHRpcqbNm
# RT @EricBoehlert: dozens in attendance https://t.co/v8tmzwNlRQ
# the vibe
# RT @RepMoBrooks: Update: So far, 36+ patriotic Congressmen signing ALL six objections to AZ GA MI NV PA WI electoral college votes.
#
# YET,…
# RT @hufflemione: Happy birthday Hayao Miyazaki 🎉
#
# A co-founder of Studio Ghibli, he also directed some films with Ghibli, Castle in the Sky…
# @parlertakes Apple Maps.  Just now https://t.co/0LS42DfA4i
# HSJSHJDBD ITS NOT MY FAULT YOU DONT KNOW HOW TO TYPE
# RT @ericuman: More than *45 percent* of tests in Alabama are coming back positive.
#
# Part of a big surge in the South.
#
# https://t.co/zXZBQ…
# RT @psychobunNSFW: the first fast sktech made for @ReverTweetin .. but with extra sketch bcs I like buns (?
# now there is 3 slots 🐰🐰🐰 https:…
# ...

# %%
aa[0]['text']
# Out:
# 'RT @HarbRimah: How AI Is Transforming Cybersecurity https://t.co/fNsBLrxY2K \n\n#MachineLearning #DataScience #Python #AI #100DaysOfCode #DEV…'

# %%
# Convert list of dictionaries (tweets) to a pandas DataFrame
df = pd.DataFrame(aa)
df.head()
# Out:
#                        created_at  ...                                     extended_tweet
# 0  Mon Jan 04 00:36:26 +0000 2021  ...                                                NaN
# 1  Mon Jan 04 00:36:27 +0000 2021  ...  {'full_text': 'Finally #Junta is gone in ET, @...
# 2  Mon Jan 04 00:36:33 +0000 2021  ...                                                NaN
# 3  Mon Jan 04 00:36:33 +0000 2021  ...                                                NaN
# 4  Mon Jan 04 00:36:34 +0000 2021  ...                                                NaN
#
# [5 rows x 30 columns]

# %%
# this is another way
#===============================================================================
# if __name__ == '__main__':

#     #This handles Twitter authetification and the connection to Twitter Streaming API
#     l = StdOutListener()

#     auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
#     auth.set_access_token(ACCESS_KEY , ACCESS_SECRET )
#     stream = Stream(auth, l)

#     #This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
#     stream.filter(languages=["en"], track=['python', 'javascript', 'ruby'], )

# %% [markdown]
# ### Download Dataset

# %%
# rowlimit = 500              # this limits the tweets to a manageable number
# data = pd.read_csv('full-corpus.csv', nrows = rowlimit)

dataset = pd.read_csv('twitter2500.csv', sep='\t')
dataset.head()
# Out:
#    Unnamed: 0  ...                                         user_place
# 0           0  ...  {'id': '04b327ef54f3632d', 'url': 'https://api...
# 1           1  ...  {'id': 'fa37e818b629e4ea', 'url': 'https://api...
# 2           2  ...  {'id': '009924a469d7ace1', 'url': 'https://api...
# 3           3  ...  {'id': '3b77caf94bfc81fe', 'url': 'https://api...
# 4           4  ...  {'id': '80f128c34d2549c6', 'url': 'https://api...
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Extract tweets in English

# %%
# this is a normal way to extract information. here one can use simple FOR loop
# and IF statements
tweets = []
for j in range(len(dataset)):
    if dataset.lang[j]=='en':
        tweets.append(dataset.text[j])
tweets[:10]
# Out:
# ['Pacioretty scored a goal. \r\n\r\nWhat a night it’s been for the Habs #GoHabsGo',
#  'fucking tired of people putting me on pause when we facetime https://t.co/HSqRAn81rQ',
#  'There are alot of things i wud do, and you are one of them',
#  '@halialmanza Aaaww princess thank you ily 😔❤️ I wish he would think the same...',
#  'Making a Red Turn around the bases! @redturn2',
#  'Happy birthday bby boy @JaysonGobble',
#  '@AndreasC466. A really good read worth a moment of your busy time https://t.co/hMAUAUSTWG',
#  'I can’t believe Akala came to my uni and I missed it 😓 https://t.co/xLgF3AUdD2',
#  'Wildling on the run!!!',
#  'Omg my heart  #ThisIsUs']

# %%
# Here, we do the same but in an intelligent way

# df= dataset.loc[dataset["lang"]== 'en', ["ID","text"]]
df = dataset.loc[dataset["lang"]== 'en', ["text"]]

# as you can see, the index of the new dataframe is not sorted
# so, the following command does it
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                                    text
# 0     Pacioretty scored a goal. \r\n\r\nWhat a night...
# 1     fucking tired of people putting me on pause wh...
# 2     There are alot of things i wud do, and you are...
# 3     @halialmanza Aaaww princess thank you ily 😔❤️ ...
# 4         Making a Red Turn around the bases! @redturn2
# ...                                                 ...
# 1166  Adam Burish is amazing as a studio host for th...
# 1167                     THAT!! https://t.co/jjNWbK6Nfg
# 1168  WEST COAST you were incredible!! Thank you for...
# 1169  Make sure you remember to clear out your ice m...
# 1170  I can’t believe my baby is already almost a mo...
#
# [1171 rows x 1 columns]

# %% [markdown]
# # **Natural Language Processing**
# Natural Language Processing (**NLP**) is the technology used to aid computers to understand the human’s natural language. It’s not an easy task teaching machines to understand how we communicate.

# %% [markdown]
# **Syntactic analysis** and **semantic analysis** are the main techniques used to complete Natural Language Processing tasks.
#
#
# 1.   **Syntax**
# > Syntax refers to **the arrangement of words in a sentence such that they make grammatical sense**. In NLP, syntactic analysis is used to assess how the natural language aligns with the grammatical rules. Computer algorithms are used to apply grammatical rules to a group of words and derive meaning from them.
#   1.   **Lemmatization**: It entails reducing the various inflected forms of a word into a single form for easy analysis.
#   2.   **Morphological segmentation**: It involves dividing words into individual units called morphemes.
#   3.   **Word segmentation**: It involves dividing a large piece of continuous text into distinct units.
#   4.   **Part-of-speech tagging**: It involves identifying the part of speech for every word.
#   5.   **Parsing**: It involves undertaking grammatical analysis for the provided sentence.
#   6.   **Sentence breaking**: It involves placing sentence boundaries on a large piece of text.
#   7.   **Stemming**: It involves cutting the inflected words to their root form
#
#
# 2.   **Semantics**
# > Semantics refers to the meaning that is conveyed by a text. Semantic analysis is one of the difficult aspects of Natural Language Processing that has not been fully resolved yet.
# It involves applying computer algorithms to understand the meaning and interpretation of words and how sentences are structured
#   1.   **Named entity recognition (NER)**: It involves determining the parts of a text that can be identified and categorized into preset groups. Examples of such groups include names of people and names of places.
#   2.   **Word sense disambiguation**: It involves giving meaning to a word based on the context.
#   3.   **Natural language generation**: It involves using databases to derive semantic intentions and convert them into human language.

# %% [markdown]
# ## **Why Python?**
# Python is a simple yet powerful programming language with excellent functionality for processing linguistic data. therefore, We chose Python because
# * it has a shallow learning curve,
# * its syntax and semantics are transparent, and
# * it has good string-handling functionality.
# * As an interpreted language, Python facilitates interactive exploration.
# * As an object-oriented language, Python permits data and methods to be encapsulated and re-used easily.
# * As a dynamic language, Python permits attributes to be added to objects on the fly, and permits variables to be typed dynamically, facilitating rapid development.
# * Python comes with an extensive standard library, including components for graphical programming, numerical processing, and web connectivity.
# * Python is heavily used in industry, scientific research, and education around the world.

# %% [markdown]
# ## **NLTK library**
# **Natural Language Toolkit** (NLTK) defines an infrastructure that can be used to build NLP programs in Python. it provides basic classes for representing data relevant to natural language processing; standard interfaces for performing tasks mentioned above.
#
# NLTK comes with extensive documentation.
# >
# ---
# NLTK was originally created in *2001* as part of a computational linguistics course in the Department of Computer and Information Science at the ***University of Pennsylvania***.
#
# Since then it has been developed and expanded with the help of dozens of contributors. It has now been adopted in courses in dozens of universities, and serves as the basis of many research projects.
#
# it was designed with four primary goals in mind
# * Simplicity
# > To provide an intuitive framework along with substantial building blocks, giving users a practical knowledge of NLP without getting bogged down in the tedious house-keeping usually associated with processing annotated language data.
# * Consistency
# > To provide a uniform framework with consistent interfaces and data structures, and easily guessable method names.
# * Extensibility
# > To provide a structure into which new software modules can be easily accommodated, including alternative implementations and competing approaches to the same task.
# * Modularity
# >To provide components that can be used independently without needing to understand the rest of the toolkit.

# %%
# Now, it's time to analyze tweets!
# there are two approaches:
#               i) you can insert columns associated with "tokenized words" and
#                  "hastags" for instance.
#              ii) you can store them in separate arrays or lists.

# %%
# Once you’ve installed NLTK, start up the Python interpreter, and install the
#data required by typing the following two commands at the Python prompt,
import string
import operator
from collections import Counter

import nltk
#nltk.download()

# Once the data is downloaded to your machine, you can load some of it using the
# Python interpreter.

# %%
# tokenizing:
#     |word tokenizing
#     |sentence tokenizing

# there are two terms: lexicon and corporas
# corpora = body of the text.
# lexicon = words and their means such as bull in general English and investment

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
example_text = df.text[0]
example_text
# Out:
# 'Pacioretty scored a goal. \r\n\r\nWhat a night it’s been for the Habs #GoHabsGo'

# %%
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via','’','[^a-zA-Z]',"#\S+|http\S+"]

# %%
sent_txt = sent_tokenize(example_text)
word_txt = word_tokenize(example_text)

print(sent_txt)
print(word_txt)
print(len(sent_txt))
print(len(word_txt))
# Out:
# ['Pacioretty scored a goal.', 'What a night it’s been for the Habs #GoHabsGo']
# ['Pacioretty', 'scored', 'a', 'goal', '.', 'What', 'a', 'night', 'it', '’', 's', 'been', 'for', 'the', 'Habs', '#', 'GoHabsGo']
# 2
# 17

# %%
# llet us to store hashtags in adifferent list
hshtg = [tg[1:] for tg in df.text[0].split() if tg.startswith('#')]
hshtg
# Out:
# ['GoHabsGo']

# %%
for txt in sent_txt:
  print(txt)
# Out:
# Pacioretty scored a goal.
# What a night it’s been for the Habs #GoHabsGo

# %%
# Now we eliminate all punctuations, stopwords, and other unnecessary terms from
# the text
#==== old methods ==============================================================
# filtered_wrds = []
# for term in word_txt:
#   if term not in stop:
#     filtered_wrds.append(term)
# print(filtered_wrds)

#=== Advance coding ============================================================
terms_stop = [term for term in word_txt if term not in stop]
terms_stop
# Out:
# ['Pacioretty', 'scored', 'goal', 'What', 'night', 'Habs', 'GoHabsGo']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
[ps.stem(w) for w in terms_stop]
# Out:
# ['pacioretti', 'score', 'goal', 'what', 'night', 'hab', 'gohabsgo']

# %%
# from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
# nltk.download('averaged_perceptron_tagger')

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(example_text)
tokenized = custom_sent_tokenizer.tokenize(example_text)

# %%
tokenized
# Out:
# ['Pacioretty scored a goal.', 'What a night it’s been for the Habs #GoHabsGo']

# %% [markdown]
# in the case of Categorizing and A part-of-speech (POS) tagging with NLTK, one can use the following abreviations:
#
# Tag	| Meaning | English Examples
# --- | --- | ---
# CC | coordinating conjunction |
# CD | cardinal digit |
# DT | determiner |
# EX | existential | there (like: “there is” … think of it like “there exists”)
# FW | foreign word |
# IN | preposition/subordinating conjunction
# JJ | adjective | big
# JJR | adjective, comparative | ‘bigger’
# JJS | adjective, superlative | ‘biggest’
# LS | list marker | 1)
# MD | modal could, | will
# NN | noun, singular | ‘desk’
# NNS | noun plural | ‘desks’
# NNP | proper noun, singular | ‘Harrison’
# NNPS | proper noun, plural | ‘Americans’
# PDT | predeterminer | ‘all the kids’
# POS | possessive ending parent’s
# PRP | personal pronoun | I, he, she
# PRP | possessive pronoun | my, his, hers
# RB | adverb | very, silently,
# RBR | adverb, comparative | better
# RBS | adverb, superlative | best
# RP | particle | give up
# VB | verb, base form | take
# VBD | verb, past tense | took
# VBG | verb, gerund/present participle | taking
# VBN | verb, past participle | taken
# VBP | verb, sing. present, non-3d | take
# VBZ | verb, 3rd person sing. present | takes
# WDT | wh-determiner | which
# WP | wh-pronoun | who, what
# WP$ | possessive wh-pronoun | whose
# WRB | wh-abverb | where, when

# %% [markdown]
# One can use the following command to understand the meaning of the tag

# %%
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# True

# %%
nltk.help.upenn_tagset('RB')
# Out:
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...

# %%
nltk.download('averaged_perceptron_tagger')
nltk.pos_tag(terms_stop)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('Pacioretty', 'RB'),
#  ('scored', 'VBN'),
#  ('goal', 'NN'),
#  ('What', 'WP'),
#  ('night', 'NN'),
#  ('Habs', 'NNP'),
#  ('GoHabsGo', 'NNP')]

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
print([lemmatizer.lemmatize(w.lower()) for w in terms_stop])
# Out:
# ['pacioretty', 'scored', 'goal', 'what', 'night', 'habs', 'gohabsgo']

# %%
lemmatizer.lemmatize("coming")
# Out:
# 'coming'

# %%
lemmatizer.lemmatize("coming", 'v')
#===============================================================================
# pos_refs = {'n': ['NN', 'NNS', 'NNP', 'NNPS'],
#            'v': ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'],
#            'r': ['RB', 'RBR', 'RBS'],
#            'a': ['JJ', 'JJR', 'JJS']}
# Out:
# 'come'

# %%
nltk.FreqDist(terms_stop)
# Out:
# FreqDist({'GoHabsGo': 1,
#           'Habs': 1,
#           'Pacioretty': 1,
#           'What': 1,
#           'goal': 1,
#           'night': 1,
#           'scored': 1})

# %%
# Note that the output of word_tokenize() is a list. So we aim to have list of
# all words in tweets
word_tokenize(df.text[0])
# Out:
# ['Pacioretty',
#  'scored',
#  'a',
#  'goal',
#  '.',
#  'What',
#  'a',
#  'night',
#  'it',
#  '’',
#  's',
#  'been',
#  'for',
#  'the',
#  'Habs',
#  '#',
#  'GoHabsGo']

# %% [markdown]
# #### All in One

# %%
# method 1
tokenized_tweets = []
for i in range(len(df)) :
  tk = word_tokenize(df.text[i])
  for j  in tk:
    tokenized_tweets.append(j)

# method 2
#create a new column contains a tokenized words
df["tokenized"] = df["text"].apply(nltk.word_tokenize)

tk = [df.tokenized[i] for i in range(len(df))]
# flattened = [val for sublist in list_of_lists for val in sublist]
flattened = [word for sublist in tk for word in sublist]

# %%
print(len(tokenized_tweets),len(flattened))
# Out:
# 16927 16927

# %%
terms_stop = [term for term in flattened if term not in stop]
terms_stop = [re.sub('[^a-zA-Z]',' ', term) for term in terms_stop]
terms_stop
# Out:
# ['Pacioretty',
#  'scored',
#  'goal',
#  'What',
#  'night',
#  'Habs',
#  'GoHabsGo',
#  'fucking',
#  'tired',
#  'people',
#  'putting',
#  'pause',
#  'facetime',
#  'https',
#  '  t co HSqRAn  rQ',
#  'There',
#  'alot',
#  'things',
#  'wud',
#  'one',
#  'halialmanza',
#  'Aaaww',
#  'princess',
#  'thank',
#  'ily',
#  '   ',
#  'I',
#  'wish',
#  'would',
#  'think',
#  '   ',
#  'Making',
#  'Red',
#  'Turn',
#  'around',
#  'bases',
#  'redturn ',
#  'Happy',
#  'birthday',
#  'bby',
#  'boy',
#  'JaysonGobble',
#  'AndreasC   ',
#  'A',
#  'really',
#  'good',
#  'read',
#  'worth',
#  'moment',
#  'busy',
#  'time',
#  'https',
#  '  t co hMAUAUSTWG',
#  'I',
#  'believe',
#  'Akala',
#  'came',
#  'uni',
#  'I',
#  'missed',
#  ' ',
#  'https',
#  '  t co xLgF AUdD ',
#  'Wildling',
#  'run',
#  'Omg',
#  'heart',
#  'ThisIsUs',
#  'What',
#  'hell',
#  'Maryland',
#  'https',
#  '  t co  XZ BcbOPz',
#  'Uh',
#  'Oh',
#  'EarnHistory',
#  'WorldSeries',
#  ' ',
# ...

# %%
terms_stop = [ps.stem(w) for w in terms_stop]

# %%
terms_stop = [lemmatizer.lemmatize(w.lower()) for w in terms_stop]

# %%
word_freq = nltk.FreqDist(terms_stop)

# %%
keys = word_freq.keys()
values = word_freq.values()

plt.bar(keys, values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-225-251aee144d0c> in <module>()
#       2 values = word_freq.values()
#       3
# ----> 4 plt.bar(keys, values, head(10))
#
# NameError: name 'head' is not defined

# %%
plt.hist(word_freq)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-224-a2cf0c6c0482> in <module>()
# ----> 1 plt.hist(word_freq)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %% [markdown]
# # Draft

# %%
l = [[1, 2, 3], [4, 5, 6], [7], [8, 9]]

# %%
import re

# %%
twt_corpus = []
for j in range(len(df)):
    tweets2 = re.sub(r"#\S+|http\S+", "", df.tokenized[j])      #remove # and http from tweets
    tweets2 = re.sub('[^a-zA-Z]',' ', tweets2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-7fc84f752458> in <module>()
#       1 twt_corpus = []
#       2 for j in range(len(df)):
# ----> 3     tweets2 = re.sub(r"#\S+|http\S+", "", df.tokenized[j])      #remove # and http from tweets
#       4     tweets2 = re.sub('[^a-zA-Z]',' ', tweets2)
#       5     # tweets2 = tweets2.lower()
#
# /usr/lib/python3.6/re.py in sub(pattern, repl, string, count, flags)
#     189     a callable, it's passed the match object and must return
#     190     a replacement string to be used."""
# --> 191     return _compile(pattern, flags).sub(repl, string, count)
#     192
#     193 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
twt_corpus
# Out:
# ['Pacioretty scored a goal      What a night it s been for the Habs ',
#  'fucking tired of people putting me on pause when we facetime ',
#  'There are alot of things i wud do  and you are one of them',
#  ' halialmanza Aaaww princess thank you ily     I wish he would think the same   ',
#  'Making a Red Turn around the bases   redturn ',
#  'Happy birthday bby boy  JaysonGobble',
#  ' AndreasC     A really good read worth a moment of your busy time ',
#  'I can t believe Akala came to my uni and I missed it   ',
#  'Wildling on the run   ',
#  'Omg my heart  ',
#  'What the hell  Maryland  ',
#  'Uh  Oh     ',
#  ' RosLehtinen  greta  VOANews      JM Santos   Dolphin Prince Heir  Dynasty Top Oligarch  Newspaper EL TIEMPO  kills Free  ',
#  'This is so odd  Just let him sit and get him right  man  ',
#  'Prodical Son PERFORMANCE Featuring  E J  ME Eternal Journey   Roxy bar on the   th  GET YA TICKETS ASAP  ',
# ...
